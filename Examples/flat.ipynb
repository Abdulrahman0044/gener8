# %%
# !pip install dist/gener8-0.1.0-py3-none-any.whl --force-reinstall
# Out:
# Processing c:\users\abdulrahman a\gener8\dist\gener8-0.1.0-py3-none-any.whl
# Collecting pandas>=1.5.0 (from gener8==0.1.0)
#   Using cached pandas-2.3.0-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy<2.0,>=1.23.0 (from gener8==0.1.0)
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Collecting scikit-learn>=1.1.0 (from gener8==0.1.0)
#   Using cached scikit_learn-1.7.0-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Collecting torch>=1.13.0 (from gener8==0.1.0)
#   Using cached torch-2.7.1-cp312-cp312-win_amd64.whl.metadata (28 kB)
# Collecting matplotlib>=3.5.0 (from gener8==0.1.0)
#   Using cached matplotlib-3.10.3-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting seaborn>=0.11.0 (from gener8==0.1.0)
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.5.0->gener8==0.1.0)
#   Using cached contourpy-1.3.2-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.5.0->gener8==0.1.0)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.5.0->gener8==0.1.0)
#   Using cached fonttools-4.58.5-cp312-cp312-win_amd64.whl.metadata (109 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.5.0->gener8==0.1.0)
#   Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Collecting packaging>=20.0 (from matplotlib>=3.5.0->gener8==0.1.0)
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pillow>=8 (from matplotlib>=3.5.0->gener8==0.1.0)
#   Using cached pillow-11.3.0-cp312-cp312-win_amd64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.5.0->gener8==0.1.0)
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Collecting python-dateutil>=2.7 (from matplotlib>=3.5.0->gener8==0.1.0)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas>=1.5.0->gener8==0.1.0)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.5.0->gener8==0.1.0)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting scipy>=1.8.0 (from scikit-learn>=1.1.0->gener8==0.1.0)
#   Using cached scipy-1.16.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn>=1.1.0->gener8==0.1.0)
#   Using cached joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=1.1.0->gener8==0.1.0)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting filelock (from torch>=1.13.0->gener8==0.1.0)
#   Using cached filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting typing-extensions>=4.10.0 (from torch>=1.13.0->gener8==0.1.0)
#   Using cached typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting sympy>=1.13.3 (from torch>=1.13.0->gener8==0.1.0)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=1.13.0->gener8==0.1.0)
#   Using cached networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch>=1.13.0->gener8==0.1.0)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch>=1.13.0->gener8==0.1.0)
#   Using cached fsspec-2025.5.1-py3-none-any.whl.metadata (11 kB)
# Collecting setuptools (from torch>=1.13.0->gener8==0.1.0)
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib>=3.5.0->gener8==0.1.0)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=1.13.0->gener8==0.1.0)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=1.13.0->gener8==0.1.0)
#   Using cached MarkupSafe-3.0.2-cp312-cp312-win_amd64.whl.metadata (4.1 kB)
# Using cached matplotlib-3.10.3-cp312-cp312-win_amd64.whl (8.1 MB)
# Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
# Using cached pandas-2.3.0-cp312-cp312-win_amd64.whl (11.0 MB)
# Using cached scikit_learn-1.7.0-cp312-cp312-win_amd64.whl (10.7 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached torch-2.7.1-cp312-cp312-win_amd64.whl (216.1 MB)
# Using cached contourpy-1.3.2-cp312-cp312-win_amd64.whl (223 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.58.5-cp312-cp312-win_amd64.whl (2.2 MB)
# Using cached joblib-1.5.1-py3-none-any.whl (307 kB)
# Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl (71 kB)
# Using cached packaging-25.0-py3-none-any.whl (66 kB)
# Using cached pillow-11.3.0-cp312-cp312-win_amd64.whl (7.0 MB)
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached scipy-1.16.0-cp312-cp312-win_amd64.whl (38.4 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached typing_extensions-4.14.1-py3-none-any.whl (43 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached filelock-3.18.0-py3-none-any.whl (16 kB)
# Using cached fsspec-2025.5.1-py3-none-any.whl (199 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached networkx-3.5-py3-none-any.whl (2.0 MB)
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# Using cached MarkupSafe-3.0.2-cp312-cp312-win_amd64.whl (15 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: pytz, mpmath, tzdata, typing-extensions, threadpoolctl, sympy, six, setuptools, pyparsing, pillow, packaging, numpy, networkx, MarkupSafe, kiwisolver, joblib, fsspec, fonttools, filelock, cycler, scipy, python-dateutil, jinja2, contourpy, torch, scikit-learn, pandas, matplotlib, seaborn, gener8
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2
#   Attempting uninstall: mpmath
#     Found existing installation: mpmath 1.3.0
#     Uninstalling mpmath-1.3.0:
#       Successfully uninstalled mpmath-1.3.0
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2025.2
#     Uninstalling tzdata-2025.2:
#       Successfully uninstalled tzdata-2025.2
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.14.1
#     Uninstalling typing_extensions-4.14.1:
#       Successfully uninstalled typing_extensions-4.14.1
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.6.0
#     Uninstalling threadpoolctl-3.6.0:
#       Successfully uninstalled threadpoolctl-3.6.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.14.0
#     Uninstalling sympy-1.14.0:
#       Successfully uninstalled sympy-1.14.0
#   Attempting uninstall: six
#     Found existing installation: six 1.17.0
#     Uninstalling six-1.17.0:
#       Successfully uninstalled six-1.17.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 80.9.0
#     Uninstalling setuptools-80.9.0:
#       Successfully uninstalled setuptools-80.9.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.2.3
#     Uninstalling pyparsing-3.2.3:
#       Successfully uninstalled pyparsing-3.2.3
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.3.0
#     Uninstalling pillow-11.3.0:
#       Successfully uninstalled pillow-11.3.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.5
#     Uninstalling networkx-3.5:
#       Successfully uninstalled networkx-3.5
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
#   Attempting uninstall: kiwisolver
#     Found existing installation: kiwisolver 1.4.8
#     Uninstalling kiwisolver-1.4.8:
#       Successfully uninstalled kiwisolver-1.4.8
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.5.1
#     Uninstalling joblib-1.5.1:
#       Successfully uninstalled joblib-1.5.1
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.5.1
#     Uninstalling fsspec-2025.5.1:
#       Successfully uninstalled fsspec-2025.5.1
#   Attempting uninstall: fonttools
#     Found existing installation: fonttools 4.58.5
#     Uninstalling fonttools-4.58.5:
#       Successfully uninstalled fonttools-4.58.5
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.18.0
#     Uninstalling filelock-3.18.0:
#       Successfully uninstalled filelock-3.18.0
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.0
#     Uninstalling scipy-1.16.0:
#       Successfully uninstalled scipy-1.16.0
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0.post0
#     Uninstalling python-dateutil-2.9.0.post0:
#       Successfully uninstalled python-dateutil-2.9.0.post0
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.6
#     Uninstalling Jinja2-3.1.6:
#       Successfully uninstalled Jinja2-3.1.6
#   Attempting uninstall: contourpy
#     Found existing installation: contourpy 1.3.2
#     Uninstalling contourpy-1.3.2:
#       Successfully uninstalled contourpy-1.3.2
#   Attempting uninstall: torch
#     Found existing installation: torch 2.7.1
#     Uninstalling torch-2.7.1:
#       Successfully uninstalled torch-2.7.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.7.0
#     Uninstalling scikit-learn-1.7.0:
#       Successfully uninstalled scikit-learn-1.7.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.3.0
#     Uninstalling pandas-2.3.0:
#       Successfully uninstalled pandas-2.3.0
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.3
#     Uninstalling matplotlib-3.10.3:
#       Successfully uninstalled matplotlib-3.10.3
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.13.2
#     Uninstalling seaborn-0.13.2:
#       Successfully uninstalled seaborn-0.13.2
#   Attempting uninstall: gener8
#     Found existing installation: gener8 0.2.2
#     Uninstalling gener8-0.2.2:
#       Successfully uninstalled gener8-0.2.2
# Successfully installed MarkupSafe-3.0.2 contourpy-1.3.2 cycler-0.12.1 filelock-3.18.0 fonttools-4.58.5 fsspec-2025.5.1 gener8-0.1.0 jinja2-3.1.6 joblib-1.5.1 kiwisolver-1.4.8 matplotlib-3.10.3 mpmath-1.3.0 networkx-3.5 numpy-1.26.4 packaging-25.0 pandas-2.3.0 pillow-11.3.0 pyparsing-3.2.3 python-dateutil-2.9.0.post0 pytz-2025.2 scikit-learn-1.7.0 scipy-1.16.0 seaborn-0.13.2 setuptools-80.9.0 six-1.17.0 sympy-1.14.0 threadpoolctl-3.6.0 torch-2.7.1 typing-extensions-4.14.1 tzdata-2025.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 3.6.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.5.1 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.5.1 which is incompatible.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.16.0 which is incompatible.
# mostlyai-engine 1.4.2 requires pandas~=2.2.0, but you have pandas 2.3.0 which is incompatible.
# mostlyai-engine 1.4.2 requires torch<2.6.1,>=2.6.0, but you have torch 2.7.1 which is incompatible.
# s3fs 2025.3.0 requires fsspec==2025.3.0.*, but you have fsspec 2025.5.1 which is incompatible.
# streamlit 1.37.1 requires packaging<25,>=20, but you have packaging 25.0 which is incompatible.
# streamlit 1.37.1 requires pillow<11,>=7.1.0, but you have pillow 11.3.0 which is incompatible.
# torchaudio 2.6.0 requires torch==2.6.0, but you have torch 2.7.1 which is incompatible.
# torchvision 0.21.0 requires torch==2.6.0, but you have torch 2.7.1 which is incompatible.

# %%
import pandas as pd
from gener8 import Gener8Engine, Evaluator

# Initialize engine
engine = Gener8Engine()

# Load data
data = pd.read_csv(r".\flat-training (original).csv")
# Out:
# 2025-07-05 03:00:45,913 - INFO - Gener8 engine initialized

# %%
data.head()
# Out:
#    dog   cat  rabbit  deer  panda koala otter  hedgehog  squirrel  dolphin  \
# 0   10  A5DB     NaN  4.46     -2    T2  B9DE      51.8         0        1
# 1   10  A5DB     NaN  4.42      0    T3  027A      72.2         1        1
# 2   43  027A     8.0  3.11     -1    T0  B9DE      44.2         1        1
# 3   28  63D1     NaN  3.37     -1    T1  027A      41.0         0        1
# 4   82  C09E     NaN  3.07     -6    T0  B9DE      46.4         1        1
#
#    ...  blanket  button  whistle marble  wagon storybook  candle  clover  \
# 0  ...       A8       2        2      0  -0.76       -54      B2    0.38
# 1  ...       A7      16        0      0  -0.76       -48      B0    0.16
# 2  ...       A4     -25       10      0  -0.88       -39      B0    0.13
# 3  ...       A3      21        9      0  -0.85       -58      B1    0.29
# 4  ...       A7      -4       13      0  -0.85        70      B2    0.75
#
#   bubble cookie
# 0      0    C13
# 1      0    C15
# 2      0     C1
# 3      1     C5
# 4      1    C13
#
# [5 rows x 80 columns]

# %%
# Load and train
engine.load_and_train(    
    data,
    n_components=3,
    epochs=10,
    max_sample_size=10000,
    batch_size=32,
    gradient_accumulation_steps=2,
    max_training_time=3600,
    max_sequence_window=1,
    enable_flexible_generation=True,
    value_protection=True,
    rare_category_replacement_method="CONSTANT",
    differential_privacy=None)
# Out:
# 2025-07-05 03:05:39,394 - INFO - Epoch 1/10, Train G Loss: 0.6850, Train D Loss: 0.4069, Val G Loss: 0.7123, Val D Loss: 0.3509
# 2025-07-05 03:05:40,872 - INFO - Epoch 2/10, Train G Loss: 0.7963, Train D Loss: 0.3266, Val G Loss: 0.7953, Val D Loss: 0.3027
# 2025-07-05 03:05:42,496 - INFO - Epoch 3/10, Train G Loss: 0.8215, Train D Loss: 0.3193, Val G Loss: 0.8363, Val D Loss: 0.2863
# 2025-07-05 03:05:44,215 - INFO - Epoch 4/10, Train G Loss: 0.8623, Train D Loss: 0.2855, Val G Loss: 0.8483, Val D Loss: 0.2810
# 2025-07-05 03:05:45,791 - INFO - Epoch 5/10, Train G Loss: 0.8407, Train D Loss: 0.2986, Val G Loss: 0.8605, Val D Loss: 0.2773
# 2025-07-05 03:05:47,397 - INFO - Epoch 6/10, Train G Loss: 0.8604, Train D Loss: 0.2825, Val G Loss: 0.8213, Val D Loss: 0.2905
# 2025-07-05 03:05:49,571 - INFO - Epoch 7/10, Train G Loss: 0.8538, Train D Loss: 0.2798, Val G Loss: 0.8640, Val D Loss: 0.2738
# 2025-07-05 03:05:51,588 - INFO - Epoch 8/10, Train G Loss: 0.8506, Train D Loss: 0.2897, Val G Loss: 0.8516, Val D Loss: 0.2843
# 2025-07-05 03:05:53,047 - INFO - Epoch 9/10, Train G Loss: 0.8730, Train D Loss: 0.2868, Val G Loss: 0.8673, Val D Loss: 0.2849
# 2025-07-05 03:05:54,493 - INFO - Epoch 10/10, Train G Loss: 0.8539, Train D Loss: 0.3137, Val G Loss: 0.8143, Val D Loss: 0.3225

# %%
# Generate synthetic data
synthetic_data = engine.generate(100)
synthetic_data.head()
# Out:
#    dog   cat  rabbit      deer  panda koala otter   hedgehog  squirrel  \
# 0   45  248B     NaN  2.251213     -2    T2  027A  28.292242         0
# 1   50  248B     NaN  2.217370     -1    T3  027A  22.094126         0
# 2   53  39ED     NaN  2.163238     -1    T3  027A  15.926418         0
# 3   52  18FD     NaN  2.356940     -1    T2  027A  23.781590         0
# 4   47  19CE     NaN  2.333783     -1    T2  027A  28.480150         0
#
#    dolphin  ...  blanket  button  whistle marble     wagon storybook  candle  \
# 0        1  ...       A3     -27        4      0 -0.819206        42      B1
# 1        1  ...       A3     -33        7      0 -0.747742        53      B2
# 2        1  ...       A4     -51        8      0 -0.670381        84      B3
# 3        1  ...       A2     -29        8      0 -0.773700        44      B2
# 4        1  ...       A2     -22        6      0 -0.819615        36      B1
#
#      clover bubble cookie
# 0  1.705289      0    C11
# 1  1.848799      0    C11
# 2  2.237867      0    C12
# 3  1.641434      0    C10
# 4  1.566314      0    C10
#
# [5 rows x 80 columns]

# %%
# Evaluate
evaluator = Evaluator()
results = evaluator.evaluate(data, synthetic_data, output_dir="visualizations")
print(f"Average Univariate Accuracy: {results['avg_univariate_accuracy']:.4f}")
print(f"Average Bivariate Accuracy: {results['avg_bivariate_accuracy']:.4f}")
print(f"Average Trivariate Accuracy: {results['avg_trivariate_accuracy']:.4f}")
print(f"NNDR: {results['nndr']:.4f}")
print(f"DCR: {results['dcr']:.4f}")
# Out:
# 2025-07-05 03:06:07,143 - INFO - Univariate accuracy for dog: 0.6365
# 2025-07-05 03:06:07,162 - INFO - Univariate accuracy for cat: 0.0000
# 2025-07-05 03:06:07,174 - INFO - Univariate accuracy for rabbit: 0.0889
# 2025-07-05 03:06:07,188 - INFO - Univariate accuracy for deer: 0.1576
# 2025-07-05 03:06:07,204 - INFO - Univariate accuracy for panda: 0.7485
# 2025-07-05 03:06:07,219 - INFO - Univariate accuracy for koala: 0.2104
# 2025-07-05 03:06:07,233 - INFO - Univariate accuracy for otter: 0.2977
# 2025-07-05 03:06:07,251 - INFO - Univariate accuracy for hedgehog: 0.1813
# 2025-07-05 03:06:07,264 - INFO - Univariate accuracy for squirrel: 0.4588
# 2025-07-05 03:06:07,275 - INFO - Univariate accuracy for dolphin: 0.9374
# 2025-07-05 03:06:07,284 - INFO - Univariate accuracy for penguin: 0.1090
# 2025-07-05 03:06:07,298 - INFO - Univariate accuracy for turtle: 0.0978
# 2025-07-05 03:06:07,316 - INFO - Univariate accuracy for elephant: 0.5443
# 2025-07-05 03:06:07,326 - INFO - Univariate accuracy for giraffe: 0.0000
# 2025-07-05 03:06:07,343 - INFO - Univariate accuracy for lamb: 0.4133
# 2025-07-05 03:06:07,353 - INFO - Univariate accuracy for goat: 0.7110
# 2025-07-05 03:06:07,367 - INFO - Univariate accuracy for cow: 0.4361
# 2025-07-05 03:06:07,391 - INFO - Univariate accuracy for horse: 0.4985
# 2025-07-05 03:06:07,401 - INFO - Univariate accuracy for donkey: 0.0000
# 2025-07-05 03:06:07,415 - INFO - Univariate accuracy for pony: 0.0000
# 2025-07-05 03:06:07,427 - INFO - Univariate accuracy for llama: 0.2619
# 2025-07-05 03:06:07,447 - INFO - Univariate accuracy for mouse: 0.1656
# 2025-07-05 03:06:07,460 - INFO - Univariate accuracy for hamster: 0.0000
# 2025-07-05 03:06:07,481 - INFO - Univariate accuracy for guinea: 0.4472
# 2025-07-05 03:06:07,493 - INFO - Univariate accuracy for duck: 0.0000
# 2025-07-05 03:06:07,509 - INFO - Univariate accuracy for chicken: 0.7047
# 2025-07-05 03:06:07,526 - INFO - Univariate accuracy for sparrow: 0.5300
# 2025-07-05 03:06:07,545 - INFO - Univariate accuracy for parrot: 0.5844
# 2025-07-05 03:06:07,560 - INFO - Univariate accuracy for finch: 0.9771
# 2025-07-05 03:06:07,578 - INFO - Univariate accuracy for canary: 0.1021
# 2025-07-05 03:06:07,590 - INFO - Univariate accuracy for bee: 0.0501
# 2025-07-05 03:06:07,601 - INFO - Univariate accuracy for butterfly: 0.0000
# 2025-07-05 03:06:07,624 - INFO - Univariate accuracy for ladybug: 0.3052
# 2025-07-05 03:06:07,639 - INFO - Univariate accuracy for snail: 0.6175
# 2025-07-05 03:06:07,661 - INFO - Univariate accuracy for frog: 0.1530
# 2025-07-05 03:06:07,676 - INFO - Univariate accuracy for cricket: 0.3672
# 2025-07-05 03:06:07,687 - INFO - Univariate accuracy for tamarin: 0.0000
# 2025-07-05 03:06:07,702 - INFO - Univariate accuracy for wallaby: 0.0000
# 2025-07-05 03:06:07,724 - INFO - Univariate accuracy for wombat: 0.3864
# 2025-07-05 03:06:07,747 - INFO - Univariate accuracy for zebra: 0.8039
# 2025-07-05 03:06:07,761 - INFO - Univariate accuracy for flamingo: 0.2470
# 2025-07-05 03:06:07,775 - INFO - Univariate accuracy for peacock: 0.9382
# 2025-07-05 03:06:07,790 - INFO - Univariate accuracy for bat: 0.9464
# 2025-07-05 03:06:07,803 - INFO - Univariate accuracy for fox: 0.1252
# 2025-07-05 03:06:07,818 - INFO - Univariate accuracy for beaver: 0.6802
# 2025-07-05 03:06:07,829 - INFO - Univariate accuracy for monkey: 0.0000
# 2025-07-05 03:06:07,844 - INFO - Univariate accuracy for seal: 0.6784
# 2025-07-05 03:06:07,859 - INFO - Univariate accuracy for robin: 0.9880
# 2025-07-05 03:06:07,874 - INFO - Univariate accuracy for loon: 0.4086
# 2025-07-05 03:06:07,906 - INFO - Univariate accuracy for swan: 0.5456
# 2025-07-05 03:06:07,928 - INFO - Univariate accuracy for goldfish: 0.6117
# 2025-07-05 03:06:07,951 - INFO - Univariate accuracy for minnow: 0.7180
# 2025-07-05 03:06:07,968 - INFO - Univariate accuracy for mole: 0.8428
# 2025-07-05 03:06:07,980 - INFO - Univariate accuracy for shrew: 0.4727
# 2025-07-05 03:06:07,994 - INFO - Univariate accuracy for puffin: 0.0000
# 2025-07-05 03:06:08,008 - INFO - Univariate accuracy for owl: 0.9455
# 2025-07-05 03:06:08,023 - INFO - Univariate accuracy for bunny: 0.3775
# 2025-07-05 03:06:08,035 - INFO - Univariate accuracy for bear: 0.1417
# 2025-07-05 03:06:08,047 - INFO - Univariate accuracy for chipmunk: 0.1548
# 2025-07-05 03:06:08,063 - INFO - Univariate accuracy for cub: 0.6569
# 2025-07-05 03:06:08,081 - INFO - Univariate accuracy for acorn: 0.3308
# 2025-07-05 03:06:08,093 - INFO - Univariate accuracy for leaf: 0.0000
# 2025-07-05 03:06:08,101 - INFO - Univariate accuracy for cloud: 0.2470
# 2025-07-05 03:06:08,114 - INFO - Univariate accuracy for rainbow: 0.1308
# 2025-07-05 03:06:08,126 - INFO - Univariate accuracy for puddle: 0.0260
# 2025-07-05 03:06:08,147 - INFO - Univariate accuracy for berry: 0.4733
# 2025-07-05 03:06:08,165 - INFO - Univariate accuracy for apple: 0.5283
# 2025-07-05 03:06:08,176 - INFO - Univariate accuracy for honey: 0.1152
# 2025-07-05 03:06:08,197 - INFO - Univariate accuracy for pumpkin: 0.6243
# 2025-07-05 03:06:08,210 - INFO - Univariate accuracy for teddy: 0.0000
# 2025-07-05 03:06:08,223 - INFO - Univariate accuracy for blanket: 0.0000
# 2025-07-05 03:06:08,240 - INFO - Univariate accuracy for button: 0.2288
# 2025-07-05 03:06:08,260 - INFO - Univariate accuracy for whistle: 0.7318
# 2025-07-05 03:06:08,281 - INFO - Univariate accuracy for marble: 0.9028
# 2025-07-05 03:06:08,295 - INFO - Univariate accuracy for wagon: 0.5506
# 2025-07-05 03:06:08,314 - INFO - Univariate accuracy for storybook: 0.4868
# 2025-07-05 03:06:08,325 - INFO - Univariate accuracy for candle: 0.0000
# 2025-07-05 03:06:08,341 - INFO - Univariate accuracy for clover: 0.1331
# 2025-07-05 03:06:08,353 - INFO - Univariate accuracy for bubble: 0.6771
# 2025-07-05 03:06:08,366 - INFO - Univariate accuracy for cookie: 0.0000
# C:\Users\Abdulrahman A\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:580: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = self.plt.figure(figsize=self.figsize)
# Average Univariate Accuracy: 0.3706
# Average Bivariate Accuracy: nan
# Average Trivariate Accuracy: 0.8778
# NNDR: 1.0494
# DCR: 1.0000
